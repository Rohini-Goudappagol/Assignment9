# %% [markdown]
# 1. Create a User login page interface that closely resembles the provided image using Tailwind CSS. The goal is
# to ensure that your implementation captures every visual detail and layout aspect depicted in the image while
# maintaining a full mobile responsiveness.
#
#     - <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <script src="https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4"></script>
#     <title>Document</title>
# </head>
#
# <body>
#     <section class="flex items-center justify-center min-h-screen p-6">
#          <div class="flex flex-col sm:flex-row bg-white rounded-xl shadow-md w-full max-w-4xl xl:max-w-6xl overflow-hidden">
#         <!-- Left: Form -->
#         <div class="w-full sm:w-1/2 p-6 flex flex-col justify-center space-y-4">
#             <h1 class="text-xl text-center">Login</h1>
#             <p class="text-gray-600 text-center px-4 py-2">Enter your credentials to access your account</p>
#             <!-- Google Input -->
#             <input type="text"
#                 class="w-full h-12 border border-gray-400 py-2 px-4 m-2 placeholder:text-center placeholder:text-black"
#                 placeholder="Login with Google"
#                 style="background: url('logo.png') no-repeat 28% center; background-size: 20px 20px;" />
#
#                 <!-- horizontal line -->
#             <div class="flex items-center w-full my-4">
#                 <div class="flex-grow h-px bg-gray-300"></div>
#                 <span class="px-3 text-gray-500 text-sm">or</span>
#                 <div class="flex-grow h-px bg-gray-300"></div>
#             </div>
#             <!-- Email Input -->
#             <label for="email" class="px-2 self-start">Email Address</label>
#             <input type="text" placeholder="email@gmail.com" class="w-full h-12 border border-gray-400 py-2 px-4 m-2" />
#             <!-- Password + Forgot Password label -->
#             <div class="flex justify-between w-full px-2">
#                 <label for="password">Password</label>
#                 <a href="#" class="text-blue-500 text-sm">Forgot Password?</a>
#             </div>
#             <!-- Password Input -->
#             <input type="password" placeholder="Password" class="w-full h-12 border border-gray-400 py-2 px-4 m-2" />
#             <!-- Login Button -->
#             <button class="w-full h-12 bg-blue-500 px-4 py-2 text-white">Login</button>
#
#             <p class="text-sm text-gray-500">
#                 Don't have an account?
#                 <span class="text-black font-semibold">Register here</span>
#             </p>
#         </div>
#
#         <!-- Right: Image -->
#         <img src="capture.jpg" class="hidden sm:block w-1/2 object-cover" alt="Login illustration" />
#         </div>
#     </section>
#
# </body>
#
# </html>

# %% [markdown]
# 2. Create a responsive image gallery using Tailwind CSS. The gallery should display a grid of images that adjust
# their size and layout based on the screen size.
#
#     - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Image Gallery</title>
# </head>
# <body>
#
#     <section class=" py-6">
#         <div
#             class="bg-gray-100  max-w-xl sm:max-w-2xl md:max-w-4xl xl:max-w-6xl xl:pr-0 mx-auto px-4 md:px-6 xl:pb-12 py-4 rounded">
#             <!-- Centered container -->
#             <p class="text-lg font-semibold mb-4 text-left">Image Gallery</p>
#
#             <div class="flex flex-col md:flex-row items-center gap-4">
#                 <img src="capture.jpg" alt="" class="w-64 h-40 border rounded border-gray-400">
#                 <img src="capture.jpg" alt="" class="w-64 h-40 border rounded border-gray-400">
#                 <img src="capture.jpg" alt="" class="w-64 h-40 border rounded border-gray-400">
#             </div>
#         </div>
#     </section>
#
# </body>
# </html>

# %% [markdown]
# 3. Create a non-responsive dashboard using Tailwind CSS, where the dashboard should include a sidebar
# navigation menu and a main contain area. (Making it responsive is optional).
#
#     -  <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Dashboard</title>
# </head>
#
# <body>
#     <section class="flex">
#         <div class="w-1/4 bg-gray-800 h-screen ">
#             <p class="text-white text-xl text-center mt-2">Dashboard</p>
#             <div class="flex flex-col justify-between">
#
#                 <ul class="px-6 text-gray-400 mt-2">
#                     <li class="flex hover:bg-gray-600"><img src="dashboard.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 border rounded">Dashboard</li>
#                     <li class="flex hover:bg-gray-600"><img src="group.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">Team</li>
#                     <li class="flex hover:bg-gray-600"><img src="folder.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">Projects</li>
#                     <li class="flex hover:bg-gray-600"><img src="calendar.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">Calender</li>
#                     <li class="flex hover:bg-gray-600"><img src="google-docs.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">Documents</li>
#                     <li class="flex hover:bg-gray-600"><img src="file.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">Reports</li>
#                 </ul>
#
#
#                 <p class=" fixed bottom-50 px-4 text-gray-400">Your Teams</p>
#                 <ul class=" fixed bottom-10 px-6 text-gray-400 mt-2">
#                     <li class="flex hover:bg-gray-600"><img src="group.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">PW Skills</li>
#                     <li class="flex hover:bg-gray-600"><img src="group.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">PW Labs</li>
#                     <li class="flex hover:bg-gray-600"><img src="group.png" alt=""
#                             class=" h-10 w-10 bg-gray-200 mr-2 mt-2 border rounded">PW. IOI</li>
#
#                 </ul>
#
#             </div>
#         </div>
#         <div class="w-3/4 bg-gray-200 h-screen">
#             <div class=" flex items-center  justify-between h-10 bg-white mt-2 p-2 w-11/12 mx-auto p-4 shadow-md">
#                 <div class="flex gap-2 items-center ">
#                     <img src="profile-user.png" alt="img" class="h-5 w-5 ">
#                     <p class="">Profile</p>
#                 </div>
#                 <div class="flex items-end gap-2">
#                     <img src="search.png" alt="img" class="h-5 w-5">
#                     <img src="bell.png" alt="img" class="h-5 w-5">
#                 </div>
#             </div>
#         </div>
#     </section>
# </body>
#
# </html>
